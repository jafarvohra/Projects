# %% [markdown]
# # ASL Computer Vision

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

import keras
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
class SignLanguage:
    def __init__(self):
        self.model = None

        self.data = {
            "train": None,
            "test" : None
        }
        self.create_model()

    def create_model(self):
        """
        Create a CNN model and save it to self.model
        """
        model = Sequential()

        model.add(Conv2D(32,kernel_size=(3,3),strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
        model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='same'))
        model.add(Dropout(rate=0.25))

        model.add(Conv2D(64,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
        model.add(MaxPooling2D((2,2),2,padding='same'))
        model.add(Dropout(rate=0.25))

        model.add(Conv2D(128,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
        model.add(MaxPooling2D((2,2),2,padding='same'))
        model.add(Dropout(rate=0.25))

        model.add(Flatten())
        model.add(keras.layers.Dense(128, activation='relu'))
        model.add(Dense(units=25,activation='softmax'))

        model.compile('adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

        self.model = model

    def prepare_data(self, images, labels):
        """
        Use this method to normalize the dataset and split it into train/test.
        Save your data in self.data["train"] and self.data["test"] as a tuple
        of (images, labels)
        :param images numpy array of size (num_examples, 28*28)
        :param labels numpy array of size (num_examples, )
        """
        x_train, x_test, y_train, y_test = train_test_split(images, labels,
                                                                    test_size = 0.3,
                                                                    random_state = 12345)

        x_train = x_train.reshape(x_train.shape[0], *(28, 28, 1))
        x_test = x_test.reshape(x_test.shape[0], *(28, 28, 1))

        y_train = to_categorical(y_train, num_classes = 25)
        y_test = to_categorical(y_test, num_classes = 25)

        self.data = {
            "train": (x_train, y_train),
            "test" : (x_test, y_test)
        }

    def train(self, batch_size:int=128, epochs:int=50, verbose:int=1):
        """
        Use model.fit() to train your model. Make sure to return the history for a neat visualization.
        :param batch_size The batch size to use for training
        :param epochs     Number of epochs to use for training
        :param verbose    Whether or not to print training output
        """
        history = self.model.fit(self.data["train"][0],
                                 self.data["train"][1],
                                 batch_size=batch_size,
                                 epochs = epochs,
                                 verbose = verbose,
                                 validation_data=(self.data["test"]),
                                 shuffle=1)
        return history

    def predict(self, data):
        """
        Use the trained model to predict labels for test data.
        :param data: numpy array of test images
        :return a numpy array of test labels. array size = (num_examples, )
        """
        test_data = data.reshape(data.shape[0], *(28, 28, 1))
        return np.argmax(self.model.predict(test_data), axis=1)

    def visualize_data(self, data):
        """
        Visualizing the hand gestures
        :param data: numpy array of images
        """
        if data is None: return

        nrows, ncols = 5, 5
        fig, axs = plt.subplots(nrows, ncols, figsize=(10, 10), sharex=True, sharey=True)
        plt.subplots_adjust(wspace=0, hspace=0)

        for i in range(nrows):
            for j in range(ncols):
                axs[i][j].imshow(data[0][i*ncols+j].reshape(28, 28), cmap='gray')
        plt.show()

    def visualize_accuracy(self, history):
        """
        Plots out the accuracy measures given a keras history object
        :param history: return value from model.fit()
        """
        if history is None: return

        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title("Accuracy")
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.legend(['train','test'])
        plt.show()

# %%
if __name__=="__main__":
    train = pd.read_csv('train.csv')
    test  = pd.read_csv('test.csv')

    train_labels, test_labels = train['label'].values, test['label'].values
    train.drop('label', axis=1, inplace=True)
    test.drop('label', axis=1, inplace=True)

    num_classes = test_labels.max() + 1
    train_images, test_images = train.values, test.values

    print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
# Out:
# (27455, 784) (27455,) (7172, 784) (7172,)

# %%
if __name__=="__main__":
    my_model = SignLanguage()
    my_model.prepare_data(train_images, train_labels)

# %%
if __name__=="__main__":
    my_model.visualize_data(my_model.data["train"])

# %%
if __name__=="__main__":
    history = my_model.train(epochs=30, verbose=1)
    my_model.visualize_accuracy(history)
# Out:
# Epoch 1/30
# 151/151 [==============================] - 14s 12ms/step - loss: 4.7617 - accuracy: 0.0468 - val_loss: 3.2037 - val_accuracy: 0.0521
# Epoch 2/30
# 151/151 [==============================] - 1s 8ms/step - loss: 3.0584 - accuracy: 0.0954 - val_loss: 2.5212 - val_accuracy: 0.2490
# Epoch 3/30
# 151/151 [==============================] - 1s 8ms/step - loss: 1.7068 - accuracy: 0.4500 - val_loss: 0.6020 - val_accuracy: 0.8289
# Epoch 4/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.7121 - accuracy: 0.7532 - val_loss: 0.2077 - val_accuracy: 0.9556
# Epoch 5/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.3713 - accuracy: 0.8694 - val_loss: 0.0679 - val_accuracy: 0.9931
# Epoch 6/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.2143 - accuracy: 0.9249 - val_loss: 0.0286 - val_accuracy: 0.9983
# Epoch 7/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.1322 - accuracy: 0.9527 - val_loss: 0.0182 - val_accuracy: 0.9976
# Epoch 8/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.1069 - accuracy: 0.9640 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 9/30
# 151/151 [==============================] - 1s 10ms/step - loss: 0.0737 - accuracy: 0.9746 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 10/30
# 151/151 [==============================] - 1s 10ms/step - loss: 0.0684 - accuracy: 0.9764 - val_loss: 0.0025 - val_accuracy: 0.9999
# Epoch 11/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0546 - accuracy: 0.9817 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 12/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 7.8943e-04 - val_accuracy: 1.0000
# Epoch 13/30
# 151/151 [==============================] - 1s 8ms/step - loss: 0.0314 - accuracy: 0.9890 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 14/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0394 - accuracy: 0.9877 - val_loss: 7.6016e-04 - val_accuracy: 0.9999
# Epoch 15/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0324 - accuracy: 0.9896 - val_loss: 4.6493e-04 - val_accuracy: 1.0000
# Epoch 16/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 4.3564e-04 - val_accuracy: 1.0000
# Epoch 17/30
# 151/151 [==============================] - 1s 8ms/step - loss: 0.0300 - accuracy: 0.9901 - val_loss: 1.9987e-04 - val_accuracy: 1.0000
# Epoch 18/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0249 - accuracy: 0.9919 - val_loss: 1.1499e-04 - val_accuracy: 1.0000
# Epoch 19/30
# 151/151 [==============================] - 2s 10ms/step - loss: 0.0202 - accuracy: 0.9924 - val_loss: 2.2823e-04 - val_accuracy: 1.0000
# Epoch 20/30
# 151/151 [==============================] - 1s 10ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 2.6514e-04 - val_accuracy: 1.0000
# Epoch 21/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 1.4885e-04 - val_accuracy: 1.0000
# Epoch 22/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 1.7222e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 151/151 [==============================] - 1s 8ms/step - loss: 0.0187 - accuracy: 0.9943 - val_loss: 5.9022e-05 - val_accuracy: 1.0000
# Epoch 24/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0314 - accuracy: 0.9907 - val_loss: 2.8019e-04 - val_accuracy: 0.9999
# Epoch 25/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0214 - accuracy: 0.9929 - val_loss: 3.7304e-04 - val_accuracy: 0.9999
# Epoch 26/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 7.1607e-05 - val_accuracy: 1.0000
# Epoch 27/30
# 151/151 [==============================] - 1s 8ms/step - loss: 0.0219 - accuracy: 0.9938 - val_loss: 1.6867e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 151/151 [==============================] - 1s 9ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 3.6485e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 151/151 [==============================] - 2s 12ms/step - loss: 0.0242 - accuracy: 0.9930 - val_loss: 5.6817e-05 - val_accuracy: 1.0000
# Epoch 30/30
# 151/151 [==============================] - 2s 11ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 4.3098e-05 - val_accuracy: 1.0000

# %%
if __name__=="__main__":
    y_pred = my_model.predict(test_images)
    accuracy = accuracy_score(test_labels, y_pred)
    print(accuracy)
# Out:
# 225/225 [==============================] - 1s 6ms/step
# 0.9617958728388176

# %%
cm = confusion_matrix(test_labels, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm)
fig, ax = plt.subplots(figsize=(10,10))
cm_display.plot(ax=ax)
